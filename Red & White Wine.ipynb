# %%
#importarea bibliotecilor
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_wine = pd.read_csv('wine-quality-white-and-red.csv')

# %%
df_wine.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
df_wine
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
#Separarea Vinuli alb
df_wine_white = df_wine[df_wine["type"]=='white']

# %%
df_wine_white
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0              0.27         0.36            20.7
# 1     white            6.3              0.30         0.34             1.6
# 2     white            8.1              0.28         0.40             6.9
# 3     white            7.2              0.23         0.32             8.5
# 4     white            7.2              0.23         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 4893  white            6.2              0.21         0.29             1.6
# 4894  white            6.6              0.32         0.36             8.0
# 4895  white            6.5              0.24         0.19             1.2
# 4896  white            5.5              0.29         0.30             1.1
# 4897  white            6.0              0.21         0.38             0.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
#Separarea Vinuli rosu
df_wine_red = df_wine[df_wine["type"]=='red']

# %%
df_wine_red
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 4898  red            7.4             0.700         0.00             1.9
# 4899  red            7.8             0.880         0.00             2.6
# 4900  red            7.8             0.760         0.04             2.3
# 4901  red           11.2             0.280         0.56             1.9
# 4902  red            7.4             0.700         0.00             1.9
# ...   ...            ...               ...          ...             ...
# 6492  red            6.2             0.600         0.08             2.0
# 6493  red            5.9             0.550         0.10             2.2
# 6494  red            6.3             0.510         0.13             2.3
# 6495  red            5.9             0.645         0.12             2.0
# 6496  red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
# Credeam la inceput ca e necesar dupa setarare de exclus coloana type
# dar dupa analiza separata am inteles ca nu trebuie
#cols_to_drop = ['type']

# %%
#excluderea coloanei Type
#df_wine_white = df_wine_white.drop(cols_to_drop, axis = 1)

# %%
df_wine_white.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4898 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  4898 non-null   object
#  1   fixed acidity         4898 non-null   float64
#  2   volatile acidity      4898 non-null   float64
#  3   citric acid           4898 non-null   float64
#  4   residual sugar        4898 non-null   float64
#  5   chlorides             4898 non-null   float64
#  6   free sulfur dioxide   4898 non-null   float64
#  7   total sulfur dioxide  4898 non-null   float64
#  8   density               4898 non-null   float64
#  9   pH                    4898 non-null   float64
#  10  sulphates             4898 non-null   float64
#  11  alcohol               4898 non-null   float64
#  12  quality               4898 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 516.6+ KB

# %%
df_wine_red.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1599 entries, 4898 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  1599 non-null   object
#  1   fixed acidity         1599 non-null   float64
#  2   volatile acidity      1599 non-null   float64
#  3   citric acid           1599 non-null   float64
#  4   residual sugar        1599 non-null   float64
#  5   chlorides             1599 non-null   float64
#  6   free sulfur dioxide   1599 non-null   float64
#  7   total sulfur dioxide  1599 non-null   float64
#  8   density               1599 non-null   float64
#  9   pH                    1599 non-null   float64
#  10  sulphates             1599 non-null   float64
#  11  alcohol               1599 non-null   float64
#  12  quality               1599 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 168.6+ KB

# %%
# Calculam datele dublicate si le excludem din ambele tipuri
sum(df_wine_white.duplicated())
# Out:
# 0

# %%
sum(df_wine_red.duplicated())
# Out:
# 240

# %%
df_wine_white.drop_duplicates(inplace = True)
# Out:
# C:\Users\Corina\AppData\Local\Temp\ipykernel_35740\2454284715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wine_white.drop_duplicates(inplace = True)

# %%
df_wine_red.drop_duplicates(inplace = True)
sum(df_wine_red.duplicated())
# Out:
# C:\Users\Corina\AppData\Local\Temp\ipykernel_35740\4230477801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wine_red.drop_duplicates(inplace = True)
# 0

# %%
df_wine_white.nunique()
# Out:
# type                      1
# fixed acidity            68
# volatile acidity        125
# citric acid              87
# residual sugar          310
# chlorides               160
# free sulfur dioxide     132
# total sulfur dioxide    251
# density                 890
# pH                      103
# sulphates                79
# alcohol                 103
# quality                   7
# dtype: int64

# %%
df_wine_red.nunique()
# Out:
# type                      1
# fixed acidity            96
# volatile acidity        143
# citric acid              80
# residual sugar           91
# chlorides               153
# free sulfur dioxide      60
# total sulfur dioxide    144
# density                 436
# pH                       89
# sulphates                96
# alcohol                  65
# quality                   6
# dtype: int64

# %%
# Metoda describe ne permite sa facem statistici 
#care rezumă tendința centrală, dispersia și forma distribuției unui set de date, excluzând valorile NaN.
df_wine_white.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    3961.000000       3961.000000  3961.000000     3961.000000
# mean        6.839346          0.280538     0.334332        5.914819
# std         0.866860          0.103437     0.122446        4.861646
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.600000
# 50%         6.800000          0.260000     0.320000        4.700000
# 75%         7.300000          0.330000     0.390000        8.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  3961.000000          3961.000000           3961.000000  3961.000000
# mean      0.045905            34.889169            137.193512     0.993790
# std       0.023103            17.210021             43.129065     0.002905
# ...

# %%
df_wine_red.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1359.000000       1359.000000  1359.000000     1359.000000
# mean        8.310596          0.529478     0.272333        2.523400
# std         1.736990          0.183031     0.195537        1.352314
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.430000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1359.000000          1359.000000           1359.000000  1359.000000
# mean      0.088124            15.893304             46.825975     0.996709
# std       0.049377            10.447270             33.408946     0.001869
# ...

# %%
# In histogramele urmatoare analizez care din urmoroarele variabile
# sunt inclinate mai spre dreapta. Analizand se observa datele din fixed acidity, alcohol
plt.hist(df_wine['fixed acidity'], color='#007979')
# Out:
# (array([  63., 1151., 3248., 1339.,  382.,  177.,   82.,   41.,    7.,
#            7.]),
#  array([ 3.8 ,  5.01,  6.22,  7.43,  8.64,  9.85, 11.06, 12.27, 13.48,
#         14.69, 15.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_wine['total sulfur dioxide'], color='#007979')
# Out:
# (array([1.088e+03, 9.790e+02, 2.049e+03, 1.514e+03, 7.210e+02, 1.340e+02,
#         8.000e+00, 2.000e+00, 1.000e+00, 1.000e+00]),
#  array([  6. ,  49.4,  92.8, 136.2, 179.6, 223. , 266.4, 309.8, 353.2,
#         396.6, 440. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_wine['pH'], color='#007979')
# Out:
# (array([  16.,  334., 1233., 2111., 1663.,  802.,  263.,   59.,   12.,
#            4.]),
#  array([2.72 , 2.849, 2.978, 3.107, 3.236, 3.365, 3.494, 3.623, 3.752,
#         3.881, 4.01 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df_wine['alcohol'], color='#007979')
# Out:
# (array([4.000e+01, 1.133e+03, 1.662e+03, 1.156e+03, 1.092e+03, 6.280e+02,
#         5.690e+02, 1.750e+02, 4.100e+01, 1.000e+00]),
#  array([ 8.  ,  8.69,  9.38, 10.07, 10.76, 11.45, 12.14, 12.83, 13.52,
#         14.21, 14.9 ]),
#  <BarContainer object of 10 artists>)

# %%
# Utilizand diagramele de dispersie dispersie ale calității în raport cu diferite variabile caracteristice, 
# determinam care au un impact pozitiv asupra calității
#Volatile Acidity, Residual Sugar, pH, Alcohol
df_wine.plot(x ='quality', y='volatile acidity', kind = 'scatter', color='#8B0A50')
# Out:
# <AxesSubplot:xlabel='quality', ylabel='volatile acidity'>

# %%
df_wine.plot(x = 'quality', y='residual sugar', kind = 'scatter', color='#8B0A50')
# Out:
# <AxesSubplot:xlabel='quality', ylabel='residual sugar'>

# %%
df_wine.plot(x = 'quality', y='pH', kind = 'scatter', color='#8B0A50')
# Out:
# <AxesSubplot:xlabel='quality', ylabel='pH'>

# %%
df_wine.plot(x = 'quality', y='alcohol', kind = 'scatter', color='#8B0A50')
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
# Determinam ce tip de vin are mai buna calitate
df_wine.groupby(['type'])['quality'].mean()
# Out:
# type
# red      5.636023
# white    5.877909
# Name: quality, dtype: float64

# %%
# Calculam nivel de aciditate (valoarea pH-ului) pe rating
# Ridicat: Mai mici 25% din valorile pH-ului
# Mai ridicat: 25% - 50% din valorile pH-ului
# Mediu: 50% - 75% din valorile pH-ului
# Scăzut: 75% - valoare maximă a pH-ului

# %%
# Vizualizarea valorilor min, 25%, 50%, 75%, max o realizam cu Pandas describe
df_wine.describe()['pH']
# Out:
# count    6497.000000
# mean        3.218501
# std         0.160787
# min         2.720000
# 25%         3.110000
# 50%         3.210000
# 75%         3.320000
# max         4.010000
# Name: pH, dtype: float64

# %%
# Excludem marginile, creem un dictionary cu valorile din intervalul min - max 
min_max_values = [ 2.72, 3.11, 3.21 ,3.32, 4.01 ]

# %%
# Etichetam valorile date
min_max_names = ['High' ,'Moderately_High' ,'Medium', 'Low' ]

# %%
# Creem o coloana noua pentru valorile noi, vizualizam datele
df_wine['acidity_levels'] = pd.cut(df_wine['pH'], min_max_values, labels=min_max_names)
df_wine.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality   acidity_levels
# 0       0.45      8.8        6             High
# ...

# %%
#Determinam calitatea medie a fiecărui nivel de aciditate cu groupby
df_wine.groupby(['quality'])['acidity_levels'].describe()
# Out:
#         count unique              top freq
# quality
# 3          30      4              Low   11
# 4         216      4             High   66
# 5        2138      4  Moderately_High  609
# 6        2835      4             High  760
# 7        1079      4              Low  293
# 8         193      4           Medium   52
# 9           5      3           Medium    2

# %%
#Calculam num. pH per culoare si calitate 
#Calculam num. pH per culoare 
#Facem raportul per culuare

# %%
sns.set_style('darkgrid')
color_counts = df_wine.groupby(['type', 'quality']).count()['pH']
color_totals = df_wine.groupby('type').count()['pH']
red_proportions = color_counts['red'] / color_totals['red']
white_proportions = color_counts['white'] / color_totals['white']


red_proportions['9'] = 0

red_bars = plt.bar(ind, red_proportions, width, color='#ff0000', alpha=.7, label='Red Wine')
white_bars = plt.bar(ind + width, white_proportions, width, color='#ffffcc', alpha=.7, label='White Wine')

plt.ylabel('Proportion')
plt.xlabel('Quality')
plt.title('Proportion by Wine Color and Quality')
labels = ['3', '4', '5', '6', '7', '8', '9']  
plt.xticks(locations, labels)

plt.legend();

# %%
#Salvam datele pentru crearea modelului
df_wine.to_csv('wine_quality_edited.csv', index=False)
